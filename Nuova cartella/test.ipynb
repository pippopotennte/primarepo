# %%
from PIL import Image 
img= Image.open("dog.jpeg")
img1= Image.open("boba.jpg")
img2= Image.open("download.jpg")
print("bye")
img
img1
img2
# Out:
# bye
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=235x215>
